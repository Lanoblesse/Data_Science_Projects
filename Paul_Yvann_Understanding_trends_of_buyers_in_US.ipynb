# %% [markdown]
# # Python Foundations Project: Austo
#
# **Marks: 60**

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ### Context
#
# In the 21st century, cars are an important mode of transportation that provides us the opportunity for personal control and autonomy. In day-to-day life, people use cars for commuting to work, shopping, visiting family and friends, etc. Research shows that more than 76% of people prevent themselves from traveling somewhere if they don't have a car. Most people tend to buy different types of cars based on their day-to-day necessities and preferences. So, it is essential for automobile companies to analyze the preference of their customers before launching a car model into the market. Austo, a UK-based automobile company aspires to grow its business into the US market after successfully establishing its footprints in the European market.
#
# In order to be familiar with the types of cars preferred by the customers and factors influencing the car purchase behavior in the US market, Austo has contracted a consulting firm. Based on various market surveys, the consulting firm has created a dataset of 3 major types of cars that are extensively used across the US market. They have collected various details of the car owners which can be analyzed to understand the automobile market of the US.
#
# ### Objective
#
# Austo's management team wants to understand the demand of the buyers and trends in the US market. They want to build customer profiles based on the analysis to identify new purchase opportunities so that they can manipulate the business strategy and production to meet certain demand levels. Further, the analysis will be a good way for management to understand the dynamics of a new market. Suppose you are a Data Scientist working at the consulting firm that has been contracted by Austo. You are given the task to create buyer's profiles for different types of cars with the available data as well as a set of recommendations for Austo. Perform the data analysis to generate useful insights that will help the automobile company to grow its business.
#
# ### Data Description
#
# austo_automobile.csv: The dataset contains buyer's data corresponding to different types of products(cars).
#
# ### Data Dictionary
#
# * Age: Age of the customer
# * Gender: Gender of the customer
# * Profession: Indicates whether the customer is a salaried or business person
# * Marital_status: Marital status of the customer
# * Education: Refers to the highest level of education completed by the customer
# * No_of_dependents: Number of dependents(partner/children/spouse) of the customer
# * Personal_loan: Indicates whether the customer availed a personal loan or not
# * House_loan: Indicates whether the customer availed house loan or not
# * Partner_working: Indicates whether the customer's partner is working or not
# * Salary: Annual Salary of the customer
# * Partner_salary: Annual Salary of the customer's partner
# * Total_salary: Annual household income (Salary + Partner_salary) of the customer's family
# * Price: Price of the car
# * Make: Car type (Hatchback/Sedan/SUV)

# %% [markdown]
# ## Importing necessary libraries

# %%
# import libraries for data manipulation
import numpy as np
import pandas as pd

# import libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## Importing the dataset

# %%
# read the data
df = pd.read_csv('austo_automobile.csv')
# returns the first 5 rows
df.head()
# Out:
#    Age Gender Profession Marital_status      Education  No_of_Dependents  \
# 0   24   Male   Salaried        Married  Post Graduate                 4
# 1   28   Male   Salaried        Married  Post Graduate                 3
# 2   23   Male   Salaried        Married       Graduate                 4
# 3   26   Male   Business        Married  Post Graduate                 4
# 4   28   Male   Business        Married  Post Graduate                 4
#
#   Personal_loan House_loan Partner_working  Salary  Partner_salary  \
# 0            No        Yes             Yes   52000           25000
# 1            No        Yes              No   68000               0
# 2           Yes        Yes              No   31000               0
# 3           Yes        Yes             Yes   66000           35000
# 4           Yes         No              No   64000               0
#
#    Total_salary  Price       Make
# 0         77000  18000  Hatchback
# 1         68000  18000  Hatchback
# ...

# %% [markdown]
# ## Data Overview

# %% [markdown]
# #### Question 1: How many rows and columns are present in the data? [0.5 mark]

# %%
# Write your code here
df.shape
# Out:
# (1581, 14)

# %%
rows = df.shape[0]
cols = df.shape[1]
print("The dataframe has", rows, "rows and" ,cols, "cols")
# Out:
# The dataframe has 1581 rows and 14 cols

# %% [markdown]
# #### Observations:
#
# * The DataFrame has 1581 rows and 14 columns

# %% [markdown]
# #### Question 2: What are the datatypes of the different columns in the dataset? [0.5 mark]

# %%
# Write your code here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1581 entries, 0 to 1580
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1581 non-null   int64
#  1   Gender            1581 non-null   object
#  2   Profession        1581 non-null   object
#  3   Marital_status    1581 non-null   object
#  4   Education         1581 non-null   object
#  5   No_of_Dependents  1581 non-null   int64
#  6   Personal_loan     1581 non-null   object
#  7   House_loan        1581 non-null   object
#  8   Partner_working   1581 non-null   object
#  9   Salary            1581 non-null   int64
#  10  Partner_salary    1581 non-null   int64
#  11  Total_salary      1581 non-null   int64
#  12  Price             1581 non-null   int64
#  13  Make              1581 non-null   object
# dtypes: int64(6), object(8)
# memory usage: 173.0+ KB

# %% [markdown]
# #### Observations:
#
# * The memory usage is about 173.0KB
# * There are a total of 1581 non-null observations in each of the columns.
# * The Dataframe has 14 columns. 6 columsn are of interger type('Age','Salary','No_of_Dependents', 'Partner_Salary','Price','Total_Salary',) .8 Columns are of object type('Make','Partner_working','House_loan','Personal_loan',,'Education','Marital_Status','Profession','Gender')

# %% [markdown]
# #### Question 3: Check the statistical summary of the data. What is the minimu, avergae, and maximum Price of the cars? [2 marks]

# %%
# Write your code here
df.describe().T
# Out:
#                    count          mean           std      min      25%  \
# Age               1581.0     32.211259      9.125477     22.0     25.0
# No_of_Dependents  1581.0      2.457938      0.943483      0.0      2.0
# Salary            1581.0  59732.447818  14278.642665  30000.0  51000.0
# Partner_salary    1581.0  19720.430108  19480.214404      0.0      0.0
# Total_salary      1581.0  79452.877925  24855.936043  30000.0  61000.0
# Price             1581.0  35597.722960  13633.636545  18000.0  25000.0
#
#                       50%      75%       max
# Age                  29.0     38.0      60.0
# No_of_Dependents      2.0      3.0       4.0
# Salary            59000.0  71000.0   90000.0
# Partner_salary    25000.0  38000.0   80000.0
# Total_salary      78000.0  96000.0  158000.0
# Price             31000.0  47000.0   70000.0

# %%
min = df['Price'].min()

# %%
max = df['Price'].max()

# %%
avg_price = round(df["Price"].mean(),2)

# %%
print("The minimum, average, and maximum price of the cars are:", min,"," ,avg_price, "," ,"and" ,max ,"respectively" )
# Out:
# The minimum, average, and maximum price of the cars are: 18000 , 35597.72 , and 70000 respectively

# %% [markdown]
# #### Observations:
#
# * The minimum, average, and maximum price of the cars are: 18000 , 35597.72 , and 70000 respectively
# * Partner_Salary has a quite a difference between the third quartile and the max indicating its distribution might be slightly skewed to the right.
# * For the most part the mean and median of all the numeric variables on the table above are not too far from the mean indicating we might not have alot of outliers to deal with.

# %% [markdown]
# #### Question 4: Are there any missing values in the data? If yes, treat them using an appropriate method.  [1 Mark]

# %%
# Write your code here
df.isnull().sum()
# Out:
# Age                 0
# Gender              0
# Profession          0
# Marital_status      0
# Education           0
# No_of_Dependents    0
# Personal_loan       0
# House_loan          0
# Partner_working     0
# Salary              0
# Partner_salary      0
# Total_salary        0
# Price               0
# Make                0
# dtype: int64

# %% [markdown]
# #### Observations:
# * There are no missing values in the dataset.

# %% [markdown]
# #### Question 5: How many cars are there of type SUV? [1 mark]

# %%
# Write your code here
df["Make"].value_counts()
# Out:
# Hatchback    884
# Sedan        460
# SUV          237
# Name: Make, dtype: int64

# %%
df["Make"].count()
# Out:
# 1581

# %% [markdown]
# #### Observations:
#
# * There are 237 cars of type SUV out of 1581 cars

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# #### **Question 6:** Explore all the variables and provide observations on their distributions. (Generally, histograms, boxplots, countplots, etc. are used for univariate exploration.) [10 marks]

# %% [markdown]
# **Numeric Variables**

# %%
#Check for correlation among Numerical variables quich and dirty analysis
num_var = ['Age','Salary','No_of_Dependents', 'Partner_salary','Price','Total_salary']

corr= df[num_var].corr()

#plot the heatmap
plt.figure(figsize = (15,7))
sns.heatmap(corr, annot = True, vmin = -1, vmax = 1, fmt = '.2f')
plt.show()

# %%
# pairplot to show the relationship between numerical variables set hue to Make
sns.pairplot(data = df, hue = "Make")
plt.show()

# %% [markdown]
# #### Observations:
#
# * As expected, partner_salary shows a high correlation with total_salary.
#
# * Price and age are also moderately highly correlated indicating older higher age might be associated with higher prices which we will explore later
#
# * Salary of the customer is also moderaly correlated with the total salary

# %% [markdown]
# #### Age

# %%
## Histogram boxplot for the Age
sns.histplot(data=df,x='Age')
plt.show()
sns.boxplot(data=df,x='Age')
plt.show()

# %% [markdown]
# #### Observations:
#
# * The average age is a little higher than the median Age indicating that the distribution is slightly right-skewed.
#
# * It appears there are many customers within the age group of 25 to 37 years of age
#
# * There are a few outliers in this column which will not be treated as they represent natural variation in the dataset

# %% [markdown]
# ##### Salary

# %%
## Histogram boxplot for the Salary
sns.histplot(data=df,x='Salary')
plt.show()
sns.boxplot(data=df,x='Salary')
plt.show()

# %% [markdown]
# #### Observations:
#
# * The average salary is a almost equal to the the median salary indicating that the distribution is nearly symmetrical although slightly right-skewed.
#
# * Comparatively there are more customers with salaries within the 50000 to 65000 salary range.
#
# * There are no outliers in this column.

# %% [markdown]
# ##### Total_salary

# %%
## Histogram boxplot for Total_salary
sns.histplot(data=df,x='Total_salary')
plt.show()
sns.boxplot(data=df,x='Total_salary')
plt.show()

# %% [markdown]
# #### Observations:
#
# * The average salary is a bit higher than the median salary indicating that the distribution might have a small amount of right-skewed although it is mostly normal.
#
# * Comparatively there are more customers with total salaries within th 60,000 to about 100,000 range.
#
# * There are a few outliers in this column, but they represent the natural variation in the dataset since some couples both work and make income closer to the 160,000 range

# %% [markdown]
# ##### Partner_salary

# %%
## Histogram boxplot for the Partner_salary
sns.histplot(data=df,x='Partner_salary')
plt.show()
sns.boxplot(data=df,x='Partner_salary')
plt.show()

# %% [markdown]
# #### Observations:
#
# * The average partner salary is lower than the median indicating that the distribution is a bit left-skewed.
#
# * Comparatively there are more customers with total salaries within th 60,000 to about 100,000 range.
#
# * There are now outliers in this column

# %% [markdown]
# ##### Price

# %%
## Histogram boxplot for the Price
sns.histplot(data=df,x='Price')
plt.show()
sns.boxplot(data=df,x='Price')
plt.show()

# %% [markdown]
# #### Observations:
#
# * The average Price is abit higher than the the median Price indicating that the distribution is slightly right-skewed.
#
# * The mode indicated a large portion of vehicules cost between 22,000 and 30,000
#
# * There are no outliers in this column.

# %% [markdown]
# **categorical Variables**

# %%
# function to create labeled barplots


def labeled_barplot(data, feature, perc=False, n=None):
    """
    Barplot with percentage at the top

    data: dataframe
    feature: dataframe column
    perc: whether to display percentages instead of count (default is False)
    n: displays the top n category levels (default is None, i.e., display all levels)
    """

    total = len(data[feature])  # length of the column
    count = data[feature].nunique()
    if n is None:
        plt.figure(figsize=(count + 2, 6))
    else:
        plt.figure(figsize=(n + 2, 6))

    plt.xticks(rotation=90, fontsize=15)
    ax = sns.countplot(
        data=data,
        x=feature,
        palette="Paired",
        order=data[feature].value_counts().index[:n],
    )

    for p in ax.patches:
        if perc == True:
            label = "{:.1f}%".format(
                100 * p.get_height() / total
            )  # percentage of each class of the category
        else:
            label = p.get_height()  # count of each level of the category

        x = p.get_x() + p.get_width() / 2  # width of the plot
        y = p.get_height()  # height of the plot

        ax.annotate(
            label,
            (x, y),
            ha="center",
            va="center",
            size=12,
            xytext=(0, 5),
            textcoords="offset points",
        )  # annotate the percentage

    plt.show()  # show the plot

# %% [markdown]
# #### Gender

# %%
labeled_barplot(df,'Gender',perc=True) ##code to plot 'Gender' column
plt.show()

# %%
df["Gender"].value_counts()
# Out:
# Male      1252
# Female     329
# Name: Gender, dtype: int64

# %% [markdown]
# #### Observations:
#
# * There are 2 unique values in the Gender category: Male and Female
# * The distribution shows males account for 79.2% of all customers by gender.

# %% [markdown]
# #### Profession

# %%
labeled_barplot(df,'Profession',perc=True) ## code to plot 'Gender' column
plt.show()

# %%
df["Profession"].value_counts()
# Out:
# Salaried    896
# Business    685
# Name: Profession, dtype: int64

# %% [markdown]
# #### Observations:
#
# * There are 2 unique values in the Profession category: Salaried and Business
# * The distribution shows Salaried account for about 56.7% of all customers by profession.

# %% [markdown]
# #### Marital_status

# %%
labeled_barplot(df,'Marital_status',perc=True)##code to plot 'Marital_status' column
plt.show()

# %%
df["Marital_status"].value_counts()
# Out:
# Married    1443
# Single      138
# Name: Marital_status, dtype: int64

# %% [markdown]
# #### Observations:
#
# * There are 2 unique values in the Profession category: Married and Single.
# * The distribution shows over 90% of customers are married

# %% [markdown]
# #### Education

# %%
labeled_barplot(df,'Education',perc=True) ## code to plot 'Education' column
plt.show()

# %%
df["Education"].value_counts()
# Out:
# Post Graduate    985
# Graduate         596
# Name: Education, dtype: int64

# %% [markdown]
# #### Observations:
# * There are 2 unique values in the Education category: Graduate and Post Graduate.
# * The distribution shows about 62.3% of customers have a Post GRaduate degree

# %% [markdown]
# #### Personal_Loan

# %%
labeled_barplot(df,'Personal_loan',perc=True) ##  code to plot 'Personal_loan' column
plt.show()

# %%
df["Personal_loan"].value_counts()
# Out:
# Yes    792
# No     789
# Name: Personal_loan, dtype: int64

# %% [markdown]
# #### Observations:
# * There are 2 unique values in the Personal loan category: Yes and No.
# * The distribution shows approximately equal amount of customers availed and didn't avail personal loan

# %% [markdown]
# #### House_Loan

# %%
labeled_barplot(df,'House_loan',perc=True) ## code to plot 'House_loan' column
plt.show()

# %%
df["House_loan"].value_counts()
# Out:
# No     1054
# Yes     527
# Name: House_loan, dtype: int64

# %% [markdown]
# #### Observations:
# * There are 2 unique values in the House loan category: Yes and No.
# * The distribution shows about double(66.7%) the amount of customers didn't avail on the house loan compared to those who did

# %% [markdown]
# #### Partner_working

# %%
labeled_barplot(df,'Partner_working',perc=True) ##code to plot 'Partner_working' column
plt.show()

# %%
df["Partner_working"].value_counts()
# Out:
# Yes    868
# No     713
# Name: Partner_working, dtype: int64

# %% [markdown]
# #### Observations:
# * There are 2 unique values in the Partner working category: Yes and No.
# * The distribution shows the difference between customers with partners working and not is slightly less than 10%
# * There is two categories of partner working status: Yes and No

# %% [markdown]
# #### Make

# %%
labeled_barplot(df,'Make',perc=True) ##code to plot 'Make' column
plt.show()

# %%
df["Make"].value_counts()
# Out:
# Hatchback    884
# Sedan        460
# SUV          237
# Name: Make, dtype: int64

# %% [markdown]
# #### Observations:
# * The distribution of Make shows the most frquent make of cars are Hatchback(about 55.9%), followed by Sedan(about 29.1%) and SUVs(15.0%)
# * Hatchbacks seem alot more popular. It would be interesting to infer if they are mostly associated with an age range
# * There are three categories of Make with are Hatchback, Sedan, and SUVs in Descending order of quantity

# %% [markdown]
# #### No_of_Dependents

# %%
labeled_barplot(df,'No_of_Dependents',perc=True) ##code to plot 'No_of_Dependents' column
plt.show()

# %%
df["No_of_Dependents"].value_counts()
# Out:
# 3    557
# 2    557
# 1    229
# 4    218
# 0     20
# Name: No_of_Dependents, dtype: int64

# %% [markdown]
# #### Observations
#
# * Most customers have 2 or 3 people depending on them. The percentage of customers with 2 or 3 partners are identical at 35.2%
# * Customers with 1 and 4 people depending on them are comparable with only 1.3% of customers having 0 dependents
# * There are five categories for number of dependents with 2 and 3 represented in equal amounts and only 20 customers with 0 dependents

# %% [markdown]
# #### Question 7: How many cars are of make Hatchback and priced above 25000. State your observations? [2 marks]

# %%
# Write the code here
df_Hatchback = df[df['Make']=='Hatchback'] ##Cars of make Hatchback
df_Hatchback
# Out:
#       Age Gender Profession Marital_status      Education  No_of_Dependents  \
# 0      24   Male   Salaried        Married  Post Graduate                 4
# 1      28   Male   Salaried        Married  Post Graduate                 3
# 2      23   Male   Salaried        Married       Graduate                 4
# 3      26   Male   Business        Married  Post Graduate                 4
# 4      28   Male   Business        Married  Post Graduate                 4
# ...   ...    ...        ...            ...            ...               ...
# 1576   28   Male   Salaried        Married  Post Graduate                 2
# 1577   23   Male   Salaried         Single       Graduate                 2
# 1578   23   Male   Business        Married       Graduate                 4
# 1579   25   Male   Business        Married  Post Graduate                 3
# 1580   28   Male   Salaried        Married       Graduate                 4
#
# ...

# %%
Hatch_above_25000 = df_Hatchback[df_Hatchback['Price']>25000] ##cars which are priced above 25000

# %%
Hatch_above_25000.shape[0]
# Out:
# 444

# %%
print("There are", Hatch_above_25000.shape[0], "Hatback cars with prices above 25,000")
# Out:
# There are 444 Hatback cars with prices above 25,000

# %% [markdown]
# #### Observations:
# * There are 444 Hatchback cars priced above 25,000

# %% [markdown]
# #### Question 8: How many owners have bought cars that were priced higher than their salary. How many of them have taken personal loan? [3 marks]

# %%
# Write the code here
df_high_P= df[df["Price"]>df["Salary"]] #owners with  cars pricing higher than their salary
df_high_P.shape
# Out:
# (96, 14)

# %%
print('The number of owners who  purchased cars pricing higher than their salary are:',df_high_P.shape[0])
# Out:
# The number of owners who  purchased cars pricing higher than their salary are: 96

# %%
df_take_loan = df_high_P[df['Personal_loan'] =='Yes']
df_take_loan.shape
print('Number of owners who have taken personal loan with cars priced higher than their salary are:', df_take_loan.shape[0])
# Out:
# Number of owners who have taken personal loan with cars priced higher than their salary are: 44

# %% [markdown]
# #### Observations:
# * Customer who have taken personal loan with cars priced higher than their salary total 44

# %% [markdown]
# ### Multivariate Analysis

# %% [markdown]
# #### Question 9: Perform a multivariate analysis to explore relationships between the important variables in the dataset. (It is a good idea to explore relations between numerical variables as well as relations between numerical and categorical variables) [15 marks]

# %%
# Write the code here

# %% [markdown]
# #### Education and Price

# %%
# Write the code here
# boxplot to show relationship between Price and Education
plt.figure(figsize=(12,5))
sns.boxplot(data = df, x='Education', y='Price')  
plt.show()

# %% [markdown]
# #### Observations:
# * The Median price between Graduate and Post Graduate are identical with a similar range
# * Education level beyond Graduate doesn't have a significant impact on Price

# %% [markdown]
# #### Profession and Price

# %%
# Write the code here
## code to visualize the relationship between Profession and Price  using boxplot
plt.figure(figsize=(12,5))
sns.boxplot(data = df, x='Profession', y='Price')  
plt.show()

# %% [markdown]
# #### Observations:
# * The Median price of Salried is less than 5000 above that of Post Business
# * Salaried have a slight higher range of prices of cars they purchse than Business. Business has a few outliers.

# %% [markdown]
# ###### Price, Age nd House Loan

# %%
# lineplot showimg relationship between three variables
plt.figure(figsize=(15,7))
sns.lineplot(data = df, x= 'Age', y='Price',hue=df["House_loan"],ci=0)
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# #### Observations:
# * Overall there is a general increase in price of cars chosen by customers as they get older
# * The increase is similar for customers who take advantage of the loan or not although there is much higher trend for customers who take advantage of the home loan
# * There sharpest increase in price is when customers reach the age of 29 and again at 45

# %% [markdown]
# ###### Price, Age and Make

# %%
# lineplot as a pointplot showing relationship between three variables
plt.figure(figsize=(15,7))
sns.lineplot(data = df, x= 'Age', y='Price',hue=df["Make"],ci=0)
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# #### Observations:
# * SUVs cost on average higher than Sedans which cost higher than Hatcbacks.
# * Younger customers below 30 years old tend to demand Hatchbacks while those between 30 and 45 mostly demand Sedans. Customers 35 and up especially starting at 45 prefer SUVs
# * There sharpest increase in price is when customers reach the age of 29 and again at 45

# %% [markdown]
# ###### Price, Number of Dependents Price and Profession

# %%
## code to visualize the relationship between Number of Dependents, Price and Profession using pointplot
plt.figure(figsize=(12,6))
sns.boxplot(data = df, x = 'No_of_Dependents',y = 'Price' ,hue=df["Profession"])  
plt.show()

# %% [markdown]
# #### Observations:
# * Customers with 0 dependents and 4 dependents have the highest ranges of car purchase.
# * Salaried individuals tend to have very high ranges of prices of cars they can purchase compared to Business individuals
# * Business individuals with 3 and 4 dependents in particular have show more outliers in car prices than any other categories.
# * Customers with 1 dependent show no significant difference in Price range of cars they are interested in based on their Professions.

# %%
## code to visualize the relationship between Gender and Price using pointplot
plt.figure(figsize=(12,6))
sns.boxplot(data = df, x = 'Gender',y = 'Price' )  
plt.show()

# %% [markdown]
# ###### Make and Salary

# %%
 ## code to visualize the relationship between make and salary using boxplot
plt.figure(figsize=(12,4))
sns.boxplot(data = df, x = 'Make', y = 'Salary', hue= "Profession") 
plt.show()

# %% [markdown]
# #### Observations:
# * Customers interested in Suvs have higher salaries ranges regardless of their Profession type.
# * The median salary for Salaried and Business professionals are simialr accross all makes.
# * There are a few outliers in the SUV make with the highest contribution from Business professionals while Salaried have highest range

# %% [markdown]
# ###### Make and Profession

# %%
##code to visualize the relationship between make and profession using countplot
plt.figure(figsize=(12,4))
sns.countplot(df["Make"],hue=df["Profession"]);

# %% [markdown]
# #### Observations:
# * Hatchbacks have the highest demand followed by Seds=ans and SUV
# * Salaried professionals tend to have higher demand(almost double) than Business professionals for the Sedan and SUV makes.
# * The demand for Hatchback is identical between the two classes of Professionals.

# %% [markdown]
# ###### Number of dependents and Make

# %%
 ## code to visualize the relationship between make and no of dependents using
plt.figure(figsize=(15,7))
sns.countplot(df["No_of_Dependents"],hue=df["Make"])
plt.show()

# %% [markdown]
# #### Observations:
# * Customers with 3 and 4 dependents have a demand for Hatchbacks and SUVs
# * Customers with 2 dependents have a comparable demand for Sedana and Hatchabcks while customers with 0 dependents have no desire for Hatchbacks

# %% [markdown]
# #### Question 10:For customers who have 3 or fewer dependents, how does the average car price vary by profession ? [2 marks]

# %%
# Get the columns for no of dependents less than or equal to 3
df_few_dep = df[df["No_of_Dependents"] <= 3]
df_few_dep
# Out:
#       Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 1      28    Male   Salaried        Married  Post Graduate                 3
# 5      36    Male   Salaried        Married  Post Graduate                 3
# 7      27    Male   Salaried        Married  Post Graduate                 3
# 8      46  Female   Salaried         Single  Post Graduate                 0
# 9      24    Male   Salaried         Single       Graduate                 2
# ...   ...     ...        ...            ...            ...               ...
# 1570   30  Female   Salaried        Married  Post Graduate                 2
# 1574   22    Male   Business        Married       Graduate                 3
# 1576   28    Male   Salaried        Married  Post Graduate                 2
# 1577   23    Male   Salaried         Single       Graduate                 2
# 1579   25    Male   Business        Married  Post Graduate                 3
#
# ...

# %%
# apply and group by profession
df_Price_Prof = df_few_dep.groupby(['Profession'])['Price'].mean().sort_values(ascending = False)
df_Price_Prof
#
# Out:
# Profession
# Salaried    37036.175711
# Business    32830.220713
# Name: Price, dtype: float64

# %% [markdown]
# #### Observations:
# * For customers with 3 or fewer dependents, the average price for Salaried is 37035.18 to 2decimal places while it is 32830.22 to 2dp for Business professionals indicating Salaried customers with 3 or fewer dependents might spend a little more.

# %% [markdown]
# #### Question 11: For customers who have availed a home loan and a personal loan, how does the price vary by profession? [3 marks]

# %%
# Write the code here

# Filter the data for House Loans and Personal Loans
df_Pers_Loan = df[df['Personal_loan'] == 'yes']
df_Hous_Loan = df[df['House_loan'] == 'yes']

df_Total_Loan = df_Hous_Loan + df_Pers_Loan
df_Price_Prof = df_Total_loan.groupby(['Profession'])['Price'].count().sort_values(ascending = False)

# %%
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Profession, Marital_status, Education, No_of_Dependents, Personal_loan, House_loan, Partner_working, Salary, Partner_salary, Total_salary, Price, Make]
# Index: []

# %%
## Boxplot code to visualize the relationship between Price and Profession
df_Total_loan = df_Hous_Loan + df_Pers_Loan
plt.figure(figsize=(12,6))
sns.boxplot(data = df, x = 'Profession', y = "Price" , hue =  df['Personal_loan'] )
# Out:
# <AxesSubplot:xlabel='Profession', ylabel='Price'>

# %%
df_Total_loan = df_Hous_Loan + df_Pers_Loan
plt.figure(figsize=(12,6))
sns.boxplot(data = df, x = 'Profession', y = "Price", hue =  df['House_loan'] )
# Out:
# <AxesSubplot:xlabel='Profession', ylabel='Price'>

# %% [markdown]
# #### Observations:
# * Professionals of the Business category have outliers in their distribution against price for those who took House and Personal loans. They also have smaller ranges of Prices they are interested in
# * Salaried customers had didn't avail on Personal or House loan have a much higher price range of cars they are interested in.

# %% [markdown]
# #### Observations:

# %% [markdown]
# ## Conclusion and Recommendations

# %% [markdown]
# #### **Question 12:** Write the conclusions and business recommendations derived from the analysis. (6 marks)

# %% [markdown]
# * Around 60% of demands of all vehicules are Hatchback, Asuto should prioritize the sell of these car categories
# * Over 90% of customers from the dataset are married. Married couples with
# *  Price and age are correlated and we discovered people 30 and above spend on more expensive cars and might be customers to target for higher end SUVs
# * Salary of the customer is correlated with the total salary. Since over 90% of customers are amrried, Austo should target customers with partners who are employed since they tend to make more expensive purchases.
# * Salaried professionals have a higher likelihood of making purchases on their vehicules since they do not have as much personal loans or house loans as Business professionals
# * Houses with 3 and 4 dependents spend more on SUVs because of the size of their families and can be targeted to generate profit
# * While Males account for over 80% of customers, they are not necessarily the highest buyers meaning Gender isn't a significant varaibleto predict price as Salary and Age can be
# * A larger dataset to infer more about customers degree before grauduation could reveal more insights since there is no difference in demands based on educational differences.

# %% [markdown]
# ___
